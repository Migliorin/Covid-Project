# %%
import json

# %%
file = open('./backup/dataset.json','r')

# %%
file
# Out:
# <_io.TextIOWrapper name='./backup/dataset.json' mode='r' encoding='UTF-8'>

# %%
data = json.load(file)

# %%
data.keys()
# Out:
# dict_keys(['version', 'data'])

# %%
total = 0
for i in data['data']:
    total += 1
    for j in i['paragraphs']:
        for k in j['qas']:
            total += 1
        total += 1

# %%
total
# Out:
# 4784

# %%
data
# Out:
# {'version': 1,
#  'data': [{'title': 'Beyoncé',
#    'paragraphs': [{'qas': [{'question': 'Quando Beyonce começou a se tornar popular?',
#        'id': '56be85543aeaaa14008c9063',
#        'answers': [{'text': 'no final dos anos 1990', 'answer_start': 269}],
#        'is_impossible': False},
#       {'question': 'Em quais áreas Beyonce competiu quando ela estava crescendo?',
#        'id': '56be85543aeaaa14008c9065',
#        'answers': [{'text': 'cantando e dançando', 'answer_start': 207}],
#        'is_impossible': False},
#       {'question': "Quando Beyoncé deixou Destiny's Child e se tornou uma cantora solo?",
#        'id': '56be85543aeaaa14008c9066',
#        'answers': [{'text': '2003', 'answer_start': 526}],
#        'is_impossible': False},
#       {'question': 'Em que cidade e estado Beyonce cresceu?',
#        'id': '56bf6b0f3aeaaa14008c9601',
#        'answers': [{'text': 'Houston, Texas', 'answer_start': 166}],
#        'is_impossible': False},
# ...

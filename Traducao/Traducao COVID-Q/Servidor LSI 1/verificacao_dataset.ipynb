# %%
import pandas as pd

# %%
df = pd.read_csv('./backup/backup_final_master_dataset.csv')
df
# Out:
#                                                pergunta  \
# 0                        o covid-19 terminará em breve?
# 1                                 o covid-19 terminará?
# 2                           quando covid-19 vai acabar?
# 3                   quando o bloqueio covid-19 termina?
# 4                                o covid-19 irá embora?
# ...                                                 ...
# 1389  o que foi feito para testar se um hospedeiro i...
# 1390  o que é um exemplo de uma medida baseada em ca...
# 1391  como a patogenicidade do covid-19 se compara c...
# 1392  Por que os civetas foram propostos como hosped...
# 1393  por que há grande incerteza na estimativa do i...
#
#                                                resposta
# 0     1º de maio, eu acho, é completamente irreal, d...
# 1     1º de maio, eu acho, é completamente irreal, d...
# 2     1º de maio, eu acho, é completamente irreal, d...
# 3     1º de maio, eu acho, é completamente irreal, d...
# ...

# %%
for i in df['resposta']:
    print(i)
# Out:
# 1º de maio, eu acho, é completamente irreal, disse o dr. ashish jha, diretor do harvard global health institute. , provavelmente por vários meses. mas você pode ter que fazer isso repetidamente, uma vez que o surto pode vir em ondas.
# 1º de maio, eu acho, é completamente irreal, disse o dr. ashish jha, diretor do harvard global health institute. , provavelmente por vários meses. mas você pode ter que fazer isso repetidamente, uma vez que o surto pode vir em ondas.
# 1º de maio, eu acho, é completamente irreal, disse o dr. ashish jha, diretor do harvard global health institute. , provavelmente por vários meses. mas você pode ter que fazer isso repetidamente, uma vez que o surto pode vir em ondas.
# 1º de maio, eu acho, é completamente irreal, disse o dr. ashish jha, diretor do harvard global health institute. , provavelmente por vários meses. mas você pode ter que fazer isso repetidamente, uma vez que o surto pode vir em ondas.
# ...
